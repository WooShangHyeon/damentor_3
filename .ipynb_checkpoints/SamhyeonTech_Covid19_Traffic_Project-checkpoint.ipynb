# %% [markdown]
# # 초기 설정 및 모듈 불러오기

# %%
import warnings 

warnings.filterwarnings(action='ignore')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import glob
import numpy as np
import plotly.graph_objs as go

from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic') 
plt.style.use("ggplot")
pd.set_option('mode.chained_assignment',  None)

# %% [markdown]
# # COVID19 진행 상황

# %%
# raw 코로나 데이터 불러오기

covid_data=pd.read_csv('data/Covid_case.csv')

# %%
# 필요 칼럼만 추출
# 코로나 일별 확진자 수 칼럼 추가
# 정수형 stateDt를 Datetime형 stateDt로 변환 후 인덱스로 설정

covid_data['daily_decideCnt']=covid_data.decideCnt.shift()-covid_data.decideCnt
covid_data_new=covid_data[['stateDt','daily_decideCnt','decideCnt','deathCnt']]
covid_data_new.index=pd.to_datetime(covid_data_new['stateDt'],format='%Y%m%d')
covid_data_new=covid_data_new.drop('stateDt',axis=1)
covid_data_new['year']=covid_data_new.index.year
covid_data_new['month']=covid_data_new.index.month
covid_data_new.head()
# Out:
#             daily_decideCnt  decideCnt  deathCnt  year  month
# stateDt
# 2021-09-25              NaN     298401    2441.0  2021      9
# 2021-09-24           3269.0     295132    2434.0  2021      9
# 2021-09-23           2433.0     292699    2427.0  2021      9
# 2021-09-22           1716.0     290983    2419.0  2021      9
# 2021-09-21           1720.0     289263    2413.0  2021      9

# %%
# 일별 확진자수 분포 확인

covid_data_new.describe().daily_decideCnt
# Out:
# count     603.000000
# mean      494.860697
# std       552.512534
# min         0.000000
# 25%        61.500000
# 50%       363.000000
# 75%       645.500000
# max      3269.000000
# Name: daily_decideCnt, dtype: float64

# %%
# 코로나 누적 확진자 시각화

plt.figure(figsize=(12,8))
plt.title('The Cumulative Trend Of COVID-19 Confirmed cases')
sns.lineplot(data=covid_data_new, x='stateDt', y='decideCnt')
# Out:
# <AxesSubplot:title={'center':'The Cumulative Trend Of COVID-19 Confirmed cases'}, xlabel='stateDt', ylabel='decideCnt'>

# %%
# 코로나 일별 확진자 시각화

plt.figure(figsize=(12,8))
plt.title('Daily Trend Of COVID-19 Confirmed Cases')
sns.lineplot(data=covid_data_new, x='stateDt', y='daily_decideCnt')
# Out:
# <AxesSubplot:title={'center':'Daily Trend Of COVID-19 Confirmed Cases'}, xlabel='stateDt', ylabel='daily_decideCnt'>

# %%
# 코로나 년도별/월별 확진자 시각화

covid_data_new.groupby(['year','month']).daily_decideCnt.sum().plot(kind='bar',figsize=(12,8), title = "The Trend Of COVID-19 Confirmed Cases Per Month")
# Out:
# <AxesSubplot:title={'center':'The Trend Of COVID-19 Confirmed Cases Per Month'}, xlabel='year,month'>

# %% [markdown]
# 위 세가지 그래프의 일별/월별/년도별 확진자 확인 결과, 2020년 3월, 2020년 8월, 2020년 12월, 2021년 8월 총 4차례의 대유행이 발생 했음을 알 수 있다.

# %%
# 대유행 기간 확진자 수 추출

covid_data_1st_pandemic=covid_data_new[(covid_data_new.year==2020) & ((covid_data_new.month==2)|(covid_data_new.month==3))]
covid_data_2nd_pandemic=covid_data_new[(covid_data_new.year==2020) & ((covid_data_new.month==8)|(covid_data_new.month==9))]
covid_data_3rd_pandemic=covid_data_new[((covid_data_new.year==2020) & ((covid_data_new.month==12)|(covid_data_new.month==11)))|
                ((covid_data_new.year==2021)&((covid_data_new.month==1)|(covid_data_new.month==2)))]
covid_data_4th_pandemic=covid_data_new[(covid_data_new.year==2021) & ((covid_data_new.month==6)|(covid_data_new.month==7)|(covid_data_new.month==8)|(covid_data_new.month==9))]

# %%
# 대유행 기간 확진자 수 시각화

fig, axes=plt.subplots(nrows=2, ncols=2)
fig.set_size_inches(20,10)

axes[0][0].set(title='Trend Of The 1st Pandemic')
axes[0][1].set(title='Trend Of The 2nd Pandemic')
axes[1][0].set(title='Trend Of The 3rd Pandemic')
axes[1][1].set(title='Trend Of The 4th Pandemic')

sns.lineplot(data=covid_data_1st_pandemic,x='stateDt', y='daily_decideCnt', ax=axes[0][0])
sns.lineplot(data=covid_data_2nd_pandemic,x='stateDt', y='daily_decideCnt', ax=axes[0][1])
sns.lineplot(data=covid_data_3rd_pandemic,x='stateDt', y='daily_decideCnt', ax=axes[1][0])
sns.lineplot(data=covid_data_4th_pandemic,x='stateDt', y='daily_decideCnt', ax=axes[1][1])
# Out:
# <AxesSubplot:title={'center':'Trend Of The 4th Pandemic'}, xlabel='stateDt', ylabel='daily_decideCnt'>

# %% [markdown]
# 4차례의 대유행이 시각화로 뚜렷하게 표현되며, 4차 대유행은 여전히 진행중이다.

# %%
# 코로나 년도별 확진자 시각화

year_covid=pd.DataFrame(covid_data_new.groupby('year')['daily_decideCnt'].sum()).T

ax = year_covid.plot(kind='barh', stacked=True, title='The COVID-19 Confirmed Cases Per Year', rot=0)
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate("%.f"%(width*100), xy=(left+width/2, bottom+height/2), ha='center', va='center')
plt.box(False)
plt.show()

# %% [markdown]
# 년도별 코로나 확진자 수를 확인해본 결과, 아직 2021년이 끝나지 않았음에도 불구하고, 2021년의 확진자 수는 2020년의 확진자 수의 4배에 근접한다.

# %% [markdown]
# # 고속도로 이용 교통량 추이

# %%
# 년도별/분기별 교통량 데이터 가져오기

traffic_2018_01=pd.read_csv('data/2018_01분기.csv',encoding='cp949')
traffic_2018_02=pd.read_csv('data/2018_02분기.csv',encoding='cp949')
traffic_2018_03=pd.read_csv('data/2018_03분기.csv',encoding='cp949')
traffic_2018_04=pd.read_csv('data/2018_04분기.csv',encoding='cp949')
traffic_2019_01=pd.read_csv('data/2019_01분기.csv',encoding='cp949')
traffic_2019_02=pd.read_csv('data/2019_02분기.csv',encoding='cp949')
traffic_2019_03=pd.read_csv('data/2019_03분기.csv',encoding='cp949')
traffic_2019_04=pd.read_csv('data/2019_04분기.csv',encoding='cp949')
traffic_2020_01=pd.read_csv('data/2020_01분기.csv',encoding='cp949')
traffic_2020_02=pd.read_csv('data/2020_02분기.csv',encoding='cp949')
traffic_2020_03=pd.read_csv('data/2020_03분기.csv',encoding='cp949')
traffic_2020_04=pd.read_csv('data/2020_04분기.csv',encoding='cp949')
traffic_2021_01=pd.read_csv('data/2021_01분기.csv',encoding='cp949')
traffic_2021_02=pd.read_csv('data/2021_02분기.csv',encoding='cp949')

# %%
# 분기별 데이터 하나의 데이터로 합치기

traffic_data=pd.concat([traffic_2018_01,traffic_2018_02,traffic_2018_03,traffic_2018_04,
                        traffic_2019_01,traffic_2019_02,traffic_2019_03,traffic_2019_04,
                        traffic_2020_01,traffic_2020_02,traffic_2020_03,traffic_2020_04,
                        traffic_2021_01,traffic_2021_02])

# %%
# 필요 칼럼만 추출
# 정수형 집계일자를 Datetime형 집계일자로 변환 후 인덱스로 설정
# 일별 년도/월/요일 칼럼 추가

traffic_data.index=traffic_data.집계일자
traffic_data=traffic_data.drop('집계일자',axis=1)
traffic_data=traffic_data[['영업소명','1종교통량', '2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량', '총교통량']]
traffic_data.index=pd.to_datetime(traffic_data.index, format='%Y%m%d')
traffic_data['year']=traffic_data.index.year 
traffic_data['month']=traffic_data.index.month
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
traffic_data['day_of_week']=traffic_data.index.dayofweek 
traffic_data.day_of_week=traffic_data.day_of_week.apply(lambda x : days[x])
traffic_data.head()
# Out:
#              영업소명  1종교통량  2종교통량  3종교통량  4종교통량  5종교통량  6종교통량  총교통량  year  \
# 집계일자
# 2018-01-01     가락    211      6      6     21     27      4   275  2018
# 2018-01-01     가락    615     14      5     14     96     26   770  2018
# 2018-01-01  가락(개)   2358     31     48     57    131    273  2898  2018
# 2018-01-01  가락(개)   7148     27     71     27    267    378  7918  2018
# 2018-01-01  가락(개)   2946     29     52     48    150    357  3582  2018
#
#             month day_of_week
# 집계일자
# 2018-01-01      1         MON
# 2018-01-01      1         MON
# 2018-01-01      1         MON
# 2018-01-01      1         MON
# 2018-01-01      1         MON

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 명칭이 불규칙하여 통일

traffic_data=traffic_data.replace('서서울영업소','서서울')
traffic_data=traffic_data.replace('서울영업소','서울')
traffic_data=traffic_data.replace('서대구영업소','서대구')
traffic_data=traffic_data.replace('북대구영업소','북대구')
traffic_data=traffic_data.replace('남대구영업소','남대구')
traffic_data=traffic_data.replace('북강릉영업소','북강릉')
traffic_data=traffic_data.replace('남강릉영업소','남강릉')
traffic_data=traffic_data.replace('강릉영업소','강릉')

# %% [markdown]
# ## 전국 교통량 분석

# %%
# 모든 곳의 톨게이트에 대한 교통량 합산

traffic_data_total=traffic_data.groupby('집계일자')['1종교통량', '2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량', '총교통량'].sum()
traffic_data_total['year']=traffic_data_total.index.year
traffic_data_total['month']=traffic_data_total.index.month
traffic_data_total['day']=traffic_data_total.index.day
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
traffic_data_total['day_of_week']=traffic_data_total.index.dayofweek
traffic_data_total.day_of_week=traffic_data_total.day_of_week.apply(lambda x : days[x])

# 년도별 저장

traffic_data_2018=traffic_data_total[traffic_data_total.year==2018]
traffic_data_2019=traffic_data_total[traffic_data_total.year==2019]
traffic_data_2020=traffic_data_total[traffic_data_total.year==2020]
traffic_data_2021=traffic_data_total[traffic_data_total.year==2021]

# 코로나 기간 저장

traffic_data_2020_2021=traffic_data_total[(traffic_data_total.year==2020)|(traffic_data_total.year==2021)]

# %%
# 요일별 차종 평균 교통량

'''
day_traffic_data_1st=traffic_data.groupby('day_of_week')['1종교통량'].mean()
day_traffic_data_remain=traffic_data.groupby('day_of_week')['2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량'].mean()
day_traffic_data_total=traffic_data.groupby('day_of_week')['총교통량'].mean() 
'''
# Out:
# "\nday_traffic_data_1st=traffic_data.groupby('day_of_week')['1종교통량'].mean()\nday_traffic_data_remain=traffic_data.groupby('day_of_week')['2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량'].mean()\nday_traffic_data_total=traffic_data.groupby('day_of_week')['총교통량'].mean() \n"

# %%
# 요일별 차종 평균 그래프 시각화

fig, axes=plt.subplots(nrows=2, ncols=3)
fig.set_size_inches(30,15)

axes[0][0].set(title='Class 1 Traffic Volume By Days')
axes[0][1].set(title='Class 2 Traffic Volume By Days')
axes[0][2].set(title='Class 3 Traffic Volume By Days')
axes[1][0].set(title='Class 4 Traffic Volume By Days')
axes[1][1].set(title='Class 5 Traffic Volume By Days')
axes[1][2].set(title='Class 6 Traffic Volume By Days')

axes[0][0].get_yaxis().get_major_formatter().set_scientific(False)
sns.barplot(x='day_of_week', y='1종교통량', data=traffic_data_total,ax=axes[0][0])
sns.barplot(x='day_of_week', y='2종교통량', data=traffic_data_total,ax=axes[0][1])
sns.barplot(x='day_of_week', y='3종교통량', data=traffic_data_total,ax=axes[0][2])
sns.barplot(x='day_of_week', y='4종교통량', data=traffic_data_total,ax=axes[1][0])
sns.barplot(x='day_of_week', y='5종교통량', data=traffic_data_total,ax=axes[1][1])
sns.barplot(x='day_of_week', y='6종교통량', data=traffic_data_total,ax=axes[1][2])
# Out:
# <AxesSubplot:title={'center':'Class 6 Traffic Volume By Days'}, xlabel='day_of_week', ylabel='6종교통량'>

# %% [markdown]
# 요일별 교통량을 확인해본 결과, 1종 교통의 교통량은 요일과 관계없이 거의 비슷하다.
# 2종부터 6종까지의 교통량은 주말이 적으며, 평일이 많다.
# 이는 근무를 위해 움직이는 사람들의 교통량에 의해서 많다고 생각되어지며,
# 개인적인 일로 움직이는 교통량을 확인하기 위해서는 주말의 교통량을 확인해볼 필요가 있다고 생각된다.
# 또한, 1종 교통량 혹은 총 교통량보다는 나머지 교통량을 확인해보는 것이 뚜렷한 변화를 확인해볼 수 있을 것 같다.

# %% [markdown]
# ### 교통량 추이 확인 - 1종 교통량

# %%
#[전국]1종교통량, 2종교통량 최소 최대값 구하기

min_first=min(traffic_data_total['1종교통량'])
max_first=max(traffic_data_total['1종교통량'])

min_second=min(traffic_data_total['2종교통량'])
max_second=max(traffic_data_total['2종교통량'])

# %%
# 요일별 차종 평균 그래프 시각화

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].get_yaxis().get_major_formatter().set_scientific(False)
axes[1].get_yaxis().get_major_formatter().set_scientific(False)

axes[0].set_ylim(min_first, max_first)
axes[1].set_ylim(min_first, max_first)

axes[0].set(title='\nTrend Of First Class Traffic On Saturday (2020-2021)\n')
axes[1].set(title='\nTrend Of First Class Traffic On Sunday (2020-2021)\n')

sns.lineplot(data=traffic_data_2020_2021[(traffic_data_total.day_of_week=='SAT')], x='집계일자', y='1종교통량', ax=axes[0])
sns.lineplot(data=traffic_data_2020_2021[(traffic_data_total.day_of_week=='SUN')], x='집계일자', y='1종교통량', ax=axes[1])
# Out:
# <AxesSubplot:title={'center':'\nTrend Of First Class Traffic On Sunday (2020-2021)\n'}, xlabel='집계일자', ylabel='1종교통량'>

# %% [markdown]
# ### 교통량 추이 확인 - 2종 교통량

# %%
# 요일별 차종 평균 그래프 시각화

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set_ylim(min_second, max_second)
axes[1].set_ylim(min_second, max_second)

axes[0].set(title='\nTrend Of Second Class Traffic On Saturday (2020-2021)\n')
axes[1].set(title='\nTrend Of Second Class Traffic On Sunday (2020-2021)\n')

sns.lineplot(data=traffic_data_2020_2021[(traffic_data_total.day_of_week=='SAT')], x='집계일자', y='2종교통량', ax=axes[0])
sns.lineplot(data=traffic_data_2020_2021[(traffic_data_total.day_of_week=='SUN')], x='집계일자', y='2종교통량', ax=axes[1])
# Out:
# <AxesSubplot:title={'center':'\nTrend Of Second Class Traffic On Sunday (2020-2021)\n'}, xlabel='집계일자', ylabel='2종교통량'>

# %% [markdown]
# ## 서울 교통량 분석

# %%
# 가장 유동인구가 많은 서울시의 교통량을 확인해보자

seoul_traffic_data=traffic_data[(traffic_data['영업소명']=='서서울')|(traffic_data['영업소명']=='동서울')|(traffic_data['영업소명']=='서울')]
seoul_traffic_data=seoul_traffic_data.groupby('집계일자')['1종교통량', '2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량', '총교통량'].sum()
seoul_traffic_data['year']=seoul_traffic_data.index.year
seoul_traffic_data['month']=seoul_traffic_data.index.month
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
seoul_traffic_data['day_of_week']=seoul_traffic_data.index.dayofweek
seoul_traffic_data.day_of_week=seoul_traffic_data.day_of_week.apply(lambda x : days[x])
seoul_traffic_data.head()
# Out:
#              1종교통량  2종교통량  3종교통량  4종교통량  5종교통량  6종교통량    총교통량  year  month  \
# 집계일자
# 2018-01-01  422993   5819  20619   2523   1392  18046  471392  2018      1
# 2018-01-02  412943  17056  29178  11928   9202  22481  502788  2018      1
# 2018-01-03  395108  20067  32127  16606  11753  22022  497683  2018      1
# 2018-01-04  402322  19891  32029  16087  11928  22179  504436  2018      1
# 2018-01-05  435052  19531  33259  15420  11579  23623  538464  2018      1
#
#            day_of_week
# 집계일자
# 2018-01-01         MON
# 2018-01-02         TUE
# 2018-01-03         WED
# 2018-01-04         THU
# 2018-01-05         FRI

# %%
#[서울]1종교통량, 2종교통량 최소 최대값 구하기

seoul_min_first=min(seoul_traffic_data['1종교통량'])
seoul_max_first=max(seoul_traffic_data['1종교통량'])

seoul_min_second=min(seoul_traffic_data['2종교통량'])
seoul_max_second=max(seoul_traffic_data['2종교통량'])

# %% [markdown]
# ### 1종 교통량

# %%
# 1종 교통량(대부분의 자가용) 분석 

plt.figure(figsize=(12,8)) 
plt.title('\nThe Seoul\'s First Class Traffic Trend (2020-2021)\n')
sns.lineplot(data=seoul_traffic_data[((seoul_traffic_data.year==2020)|(seoul_traffic_data.year==2021))], x='집계일자', y='1종교통량')
# Out:
# <AxesSubplot:title={'center':"\nThe Seoul's First Class Traffic Trend (2020-2021)\n"}, xlabel='집계일자', ylabel='1종교통량'>

# %% [markdown]
# 교통량이 갑자기 줄어드는 시기가 눈에 보이지만, 주중과 주말의 교통량 극심한 차이로 인하여 그래프 상에서 진동이 심하게 일어난다.
# 따라서 주말만 비교해 보자.

# %%
# 요일별 차종 평균 그래프 시각화

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].get_yaxis().get_major_formatter().set_scientific(False)
axes[1].get_yaxis().get_major_formatter().set_scientific(False)



axes[0].set(title='\nTrend Of Seoul\'s First Class Traffic On Saturday (2020-2021)\n')
axes[1].set(title='\nTrend Of Seoul\'s First Class Traffic On Sunday (2020-2021)\n')

sns.lineplot(data=seoul_traffic_data[(seoul_traffic_data.day_of_week=='SAT')&((seoul_traffic_data.year==2020)|(seoul_traffic_data.year==2021))], x='집계일자', y='1종교통량', ax=axes[0])
sns.lineplot(data=seoul_traffic_data[(seoul_traffic_data.day_of_week=='SUN')&((seoul_traffic_data.year==2020)|(seoul_traffic_data.year==2021))], x='집계일자', y='1종교통량', ax=axes[1])
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Seoul's First Class Traffic On Sunday (2020-2021)\n"}, xlabel='집계일자', ylabel='1종교통량'>

# %%
# 주중/ 주말 차종 평균 그래프 시각화

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set(title='\nTrend Of Seoul\'s First Class Traffic On Weekdays (2020-2021)\n')
axes[1].set(title='\nTrend Of Seoul\'s First Class Traffic On Weekend (2020-2021)\n')

sns.lineplot(data=seoul_traffic_data[((seoul_traffic_data.day_of_week=='MON')
                                    |(seoul_traffic_data.day_of_week=='TUE')
                                    |(seoul_traffic_data.day_of_week=='WED')
                                    |(seoul_traffic_data.day_of_week=='THU')
                                    |(seoul_traffic_data.day_of_week=='FRI'))
                                    &((seoul_traffic_data.year==2020)|(seoul_traffic_data.year==2021))], x='집계일자', y='1종교통량', ax=axes[0])
sns.lineplot(data=seoul_traffic_data[((seoul_traffic_data.day_of_week=='SUN')|(seoul_traffic_data.day_of_week=='SAT'))&((seoul_traffic_data.year==2020)|(seoul_traffic_data.year==2021))], x='집계일자', y='1종교통량', ax=axes[1])
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Seoul's First Class Traffic On Weekend (2020-2021)\n"}, xlabel='집계일자', ylabel='1종교통량'>

# %% [markdown]
# ### 2종 교통량
#
# 자가용이 아닌 택배 차량을 확인해 보자.
# 쿠팡, CJ 택배와 같은 화물 차양은 2종 차량으로 분류 된다.

# %%
# 2종 교통량(중형차) 요일별 차종 평균 그래프 시각화

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set(title='\nTrend Of Seoul\'s Second Class Traffic On Saturday (2020-2021)\n')
axes[1].set(title='\nTrend Of Seoul\'s Second Class Traffic On Sunday (2020-2021)\n')

sns.lineplot(data=seoul_traffic_data[(seoul_traffic_data.day_of_week=='SAT')&((seoul_traffic_data.year==2020)|(seoul_traffic_data.year==2021))], x='집계일자', y='2종교통량', ax=axes[0])
sns.lineplot(data=seoul_traffic_data[(seoul_traffic_data.day_of_week=='SUN')&((seoul_traffic_data.year==2020)|(seoul_traffic_data.year==2021))], x='집계일자', y='2종교통량', ax=axes[1])
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Seoul's Second Class Traffic On Sunday (2020-2021)\n"}, xlabel='집계일자', ylabel='2종교통량'>

# %%
# 2종 교통량(중형차) 주중/ 주말 차종 평균 그래프 시각화

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set(title='\nTrend Of Seoul\'s Second Class Traffic On Weekdays (2020-2021)\n')
axes[1].set(title='\nTrend Of Seoul\'s Second Class Traffic On Weekend (2020-2021)\n')

sns.lineplot(data=seoul_traffic_data[((seoul_traffic_data.day_of_week=='MON')
                                    |(seoul_traffic_data.day_of_week=='TUE')
                                    |(seoul_traffic_data.day_of_week=='WED')
                                    |(seoul_traffic_data.day_of_week=='THU')
                                    |(seoul_traffic_data.day_of_week=='FRI'))
                                    &((seoul_traffic_data.year==2020)|(seoul_traffic_data.year==2021))], x='집계일자', y='2종교통량', ax=axes[0])
sns.lineplot(data=seoul_traffic_data[((seoul_traffic_data.day_of_week=='SUN')|(seoul_traffic_data.day_of_week=='SAT'))&((seoul_traffic_data.year==2020)|(seoul_traffic_data.year==2021))], x='집계일자', y='2종교통량', ax=axes[1])
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Seoul's Second Class Traffic On Weekend (2020-2021)\n"}, xlabel='집계일자', ylabel='2종교통량'>

# %% [markdown]
# ## 대구 교통량 분석
#
# 코로나 19 1차 대유행발발 지역인 대구를 추가적으로 살펴 보자.

# %%
daegu_traffic_data=traffic_data[(traffic_data['영업소명']=='서대구')|(traffic_data['영업소명']=='남대구')|(traffic_data['영업소명']=='북대구')].groupby('집계일자')['1종교통량', '2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량', '총교통량'].sum()
daegu_traffic_data['year']=daegu_traffic_data.index.year
daegu_traffic_data['month']=daegu_traffic_data.index.month
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
daegu_traffic_data['day_of_week']=daegu_traffic_data.index.dayofweek
daegu_traffic_data.day_of_week=daegu_traffic_data.day_of_week.apply(lambda x : days[x])
daegu_traffic_data.head()
# Out:
#              1종교통량  2종교통량  3종교통량  4종교통량  5종교통량  6종교통량    총교통량  year  month  \
# 집계일자
# 2018-01-01  158432   1384   3607    712    516   5847  170498  2018      1
# 2018-01-02  161220   6162   7056   3431   3685   7883  189437  2018      1
# 2018-01-03  160008   7111   8303   4490   4598   7705  192215  2018      1
# 2018-01-04  161046   6983   8325   4443   4951   7736  193484  2018      1
# 2018-01-05  174056   7281   8340   4325   5110   8321  207433  2018      1
#
#            day_of_week
# 집계일자
# 2018-01-01         MON
# 2018-01-02         TUE
# 2018-01-03         WED
# 2018-01-04         THU
# 2018-01-05         FRI

# %% [markdown]
# ### 1종 교통량 분석

# %%
# 1종 교통량(대부분의 자가용) 분석 /

plt.figure(figsize=(12,8)) 
daegu_1_all=sns.lineplot(data=daegu_traffic_data[((daegu_traffic_data.year==2020)|(daegu_traffic_data.year==2021))], x='집계일자', y='1종교통량',linestyle='-', color='skyblue', marker=',')
daegu_1_all.set(title='\nTrend Of Daegu\'s First Class Traffic(2020-2021)\n')
# Out:
# [Text(0.5, 1.0, "\nTrend Of Daegu's First Class Traffic(2020-2021)\n")]

# %%
# 1종 교통량(자가용) 요일별 차종 평균 그래프 시각화

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set(title='\nTrend Of Daegu\'s First Class Traffic On Saturday (2020-2021)\n')
axes[1].set(title='\nTrend Of Daegu\'s First Class Traffic On Sunday (2020-2021)\n')

sns.lineplot(data=daegu_traffic_data[(daegu_traffic_data.day_of_week=='SAT')&((daegu_traffic_data.year==2020)|(daegu_traffic_data.year==2021))], x='집계일자', y='1종교통량',linestyle='-', color='skyblue', marker=',', ax=axes[0])
sns.lineplot(data=daegu_traffic_data[(daegu_traffic_data.day_of_week=='SUN')&((daegu_traffic_data.year==2020)|(daegu_traffic_data.year==2021))], x='집계일자', y='1종교통량',linestyle='-', color='skyblue', marker=',', ax=axes[1])
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Daegu's First Class Traffic On Sunday (2020-2021)\n"}, xlabel='집계일자', ylabel='1종교통량'>

# %%
# 1종 교통량(대부분의 자가용) 요일별 차종 평균 그래프 시각화

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set(title='\nTrend Of Daegu\'s First Class Traffic On Weekdays (2020-2021)\n')
axes[1].set(title='\nTrend Of Daegu\'s First Class Traffic On Weekend (2020-2021)\n')

sns.lineplot(data=daegu_traffic_data[((daegu_traffic_data.day_of_week=='MON')|(daegu_traffic_data.day_of_week=='TUE')|(daegu_traffic_data.day_of_week=='WED')|(daegu_traffic_data.day_of_week=='THU')|(daegu_traffic_data.day_of_week=='FRI'))&((daegu_traffic_data.year==2020)|(daegu_traffic_data.year==2021))], x='집계일자', y='1종교통량',linestyle='-', color='skyblue', marker=',', ax=axes[0])
sns.lineplot(data=daegu_traffic_data[((daegu_traffic_data.day_of_week=='SAT')|(daegu_traffic_data.day_of_week=='SUN'))&((daegu_traffic_data.year==2020)|(daegu_traffic_data.year==2021))], x='집계일자', y='1종교통량',linestyle='-', color='skyblue', marker=',', ax=axes[1])
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Daegu's First Class Traffic On Weekend (2020-2021)\n"}, xlabel='집계일자', ylabel='1종교통량'>

# %% [markdown]
# ### 2종 교통량 분석

# %%
# 2종 교통량(중형차) 분석 /

plt.figure(figsize=(12,8)) 
daegu_1_all=sns.lineplot(data=daegu_traffic_data[((daegu_traffic_data.year==2020)|(daegu_traffic_data.year==2021))], x='집계일자', y='2종교통량',linestyle='-', color='skyblue', marker=',')
daegu_1_all.set(title='\nTrend Of Daegu\'s Second Class Traffic(2020-2021)\n')
# Out:
# [Text(0.5, 1.0, "\nTrend Of Daegu's Second Class Traffic(2020-2021)\n")]

# %%
# 2종 교통량(중형차) 요일별 차종 평균 그래프 시각화

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set(title='\nTrend Of Daegu\'s Second Class Traffic On Saturday (2020-2021)\n')
axes[1].set(title='\nTrend Of Daegu\'s Second Class Traffic On Sunday (2020-2021)\n')

sns.lineplot(data=daegu_traffic_data[(daegu_traffic_data.day_of_week=='SAT')&((daegu_traffic_data.year==2020)|(daegu_traffic_data.year==2021))], x='집계일자', y='2종교통량',linestyle='-', color='skyblue', marker=',', ax=axes[0])
sns.lineplot(data=daegu_traffic_data[(daegu_traffic_data.day_of_week=='SUN')&((daegu_traffic_data.year==2020)|(daegu_traffic_data.year==2021))], x='집계일자', y='2종교통량',linestyle='-', color='skyblue', marker=',', ax=axes[1])
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Daegu's Second Class Traffic On Sunday (2020-2021)\n"}, xlabel='집계일자', ylabel='2종교통량'>

# %%
# 2종 교통량(중형차) 요일별 차종 평균 그래프 시각화

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set(title='\nTrend Of Daegu\'s Second Class Traffic On Weekdays (2020-2021)\n')
axes[1].set(title='\nTrend Of Daegu\'s Second Class Traffic On Weekend (2020-2021)\n')

sns.lineplot(data=daegu_traffic_data[((daegu_traffic_data.day_of_week=='MON')|(daegu_traffic_data.day_of_week=='TUE')|(daegu_traffic_data.day_of_week=='WED')|(daegu_traffic_data.day_of_week=='THU')|(daegu_traffic_data.day_of_week=='FRI'))&((daegu_traffic_data.year==2020)|(daegu_traffic_data.year==2021))], x='집계일자', y='2종교통량',linestyle='-', color='skyblue', marker=',', ax=axes[0])
sns.lineplot(data=daegu_traffic_data[((daegu_traffic_data.day_of_week=='SAT')|(daegu_traffic_data.day_of_week=='SUN'))&((daegu_traffic_data.year==2020)|(daegu_traffic_data.year==2021))], x='집계일자', y='2종교통량',linestyle='-', color='skyblue', marker=',', ax=axes[1])
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Daegu's Second Class Traffic On Weekend (2020-2021)\n"}, xlabel='집계일자', ylabel='2종교통량'>

# %% [markdown]
# # 코로나 확진자 VS 교통량
#
# 전국적으로 또는 지역별로 코로나 확진자 수와 교통량의 관계를 확인해보자

# %% [markdown]
# ## 확진자 수의 단위별 교통량 분석

# %%
# Covid_data_new의 datily_decideCnt를 100단위로 번주화

covid_data_new['categorize_100']=covid_data_new.daily_decideCnt//100
covid_data_new.tail()
# Out:
#             daily_decideCnt  decideCnt  deathCnt  year  month  categorize_100
# stateDt
# 2020-02-04              3.0         16       0.0  2020      2             0.0
# 2020-02-03              1.0         15       0.0  2020      2             0.0
# 2020-02-02             13.0          2       2.0  2020      2             0.0
# 2020-02-01              2.0          0       0.0  2020      2             0.0
# 2020-01-01              0.0          0       0.0  2020      1             0.0

# %%
covid_data_new.categorize_100.describe()
# Out:
# count    603.000000
# mean       4.499171
# std        5.499132
# min        0.000000
# 25%        0.000000
# 50%        3.000000
# 75%        6.000000
# max       32.000000
# Name: categorize_100, dtype: float64

# %% [markdown]
# ### [전국] 코로나 확진자수VS 교통량

# %%
# 전국 교통량 합산

traffic_data_total=traffic_data.groupby('집계일자')['1종교통량', '2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량', '총교통량'].sum()

# %% [markdown]
# 코로나19 발생 이전의 교통량은 평균 6.8*10^6이었다.

# %%
#교통량 데이터와 코로나19 확진자수 데이터를 날짜를 기준으로 병합

data_mart_total=covid_data_new.join(traffic_data_total, how='right')
data_mart_total['date']=data_mart_total.index
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
data_mart_total['day_of_week']=data_mart_total.index.dayofweek
data_mart_total.day_of_week=data_mart_total.day_of_week.apply(lambda x : days[x])
data_mart_total.decideCnt=data_mart_total.decideCnt.fillna(0)
data_mart_total.daily_decideCnt=data_mart_total.daily_decideCnt.fillna(0)
data_mart_total.deathCnt=data_mart_total.deathCnt.fillna(0)
data_mart_total['year']=data_mart_total.index.year
data_mart_total['month']=data_mart_total.index.month
data_mart_total['categorize_100']=data_mart_total.daily_decideCnt//100
data_mart_total.head()
# Out:
#             daily_decideCnt  decideCnt  deathCnt  year  month  categorize_100  \
# 집계일자
# 2018-01-01              0.0        0.0       0.0  2018      1             0.0
# 2018-01-02              0.0        0.0       0.0  2018      1             0.0
# 2018-01-03              0.0        0.0       0.0  2018      1             0.0
# 2018-01-04              0.0        0.0       0.0  2018      1             0.0
# 2018-01-05              0.0        0.0       0.0  2018      1             0.0
#
#               1종교통량   2종교통량   3종교통량   4종교통량   5종교통량   6종교통량     총교통량  \
# 집계일자
# 2018-01-01  5562671   64729  140284   36796   34705  240045  6079230
# 2018-01-02  4945308  200328  257620  163881  234282  290196  6091615
# 2018-01-03  4841053  232174  293244  212214  294425  289377  6162487
# 2018-01-04  4902656  232305  293413  209227  300632  291083  6229316
# 2018-01-05  5342859  233726  299322  209493  299666  310678  6695744
#
#                  date day_of_week
# 집계일자
# ...

# %%
# 년도별 확진자수 카테고리 분포

plt.figure(figsize=(12,10))
plt.title('\nDistribution By Unit Of The Number Of Confirmed Cases\n')
sns.countplot(x='categorize_100',data=data_mart_total,hue='year')
# Out:
# <AxesSubplot:title={'center':'\nDistribution By Unit Of The Number Of Confirmed Cases\n'}, xlabel='categorize_100', ylabel='count'>

# %% [markdown]
# 대부분은 확진자수 값은 0~12의 범주에 있다

# %%
#확진자수에 따른 평균 총교통량

plt.figure(figsize=(12,8))
sns.lineplot(x='categorize_100', y='총교통량',data=data_mart_total,hue='year')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-95b43524b9c0> in <module>
#       2
#       3 plt.figure(figsize=(12,8))
# ----> 4 sns.lineplot(x='categorize_100', y='총교통량',data=data_mart_total,hue='year')
#
# NameError: name 'data_mart_total' is not defined

# %%
#확진자수에 따른 평균 1종교통량

plt.figure(figsize=(12,8))
sns.lineplot(x='categorize_100', y='1종교통량',data=data_mart_total,hue='year')
# Out:
# <AxesSubplot:xlabel='categorize_100', ylabel='1종교통량'>

# %% [markdown]
# ### [서울] 코로나 확진자수VS 교통량

# %%
# 서울 확진자수 데이터 불러오기 및 필요 컬럼 선별

seoul_covid_data=pd.read_csv('data/서울시 코로나19 확진자 현황.csv',encoding='utf8')
seoul_covid_data=pd.DataFrame(seoul_covid_data.groupby('확진일').count()['연번'])
seoul_covid_data.columns=['daily_decideCnt']
seoul_covid_data['categorize_100']=seoul_covid_data.daily_decideCnt//100
seoul_covid_data.index=pd.to_datetime(seoul_covid_data.index)
seoul_covid_data.tail()
# Out:
#             daily_decideCnt  categorize_100
# 확진일
# 2021-10-04              521               5
# 2021-10-05              689               6
# 2021-10-06              836               8
# 2021-10-07              775               7
# 2021-10-08              712               7

# %%
#서울 2020년도 교통량 합산

Seoul_Traffic_2020_1=pd.read_csv('data/2020_Seoul_Traffic/01월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2020_2=pd.read_csv('data/2020_Seoul_Traffic/02월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2020_3=pd.read_csv('data/2020_Seoul_Traffic/03월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2020_4=pd.read_csv('data/2020_Seoul_Traffic/04월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2020_5=pd.read_csv('data/2020_Seoul_Traffic/05월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2020_6=pd.read_csv('data/2020_Seoul_Traffic/06월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2020_7=pd.read_csv('data/2020_Seoul_Traffic/07월 서울시 교통량 조사자료.csv',encoding='utf8')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2020_8=pd.read_csv('data/2020_Seoul_Traffic/08월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2020_9=pd.read_csv('data/2020_Seoul_Traffic/09월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2020_10=pd.read_csv('data/2020_Seoul_Traffic/10월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2020_11=pd.read_csv('data/2020_Seoul_Traffic/11월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2020_12=pd.read_csv('data/2020_Seoul_Traffic/12월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2020=pd.concat([Seoul_Traffic_2020_1, Seoul_Traffic_2020_2,Seoul_Traffic_2020_3, Seoul_Traffic_2020_4,
                             Seoul_Traffic_2020_5,Seoul_Traffic_2020_6,Seoul_Traffic_2020_7,Seoul_Traffic_2020_8,
                             Seoul_Traffic_2020_9,Seoul_Traffic_2020_10,Seoul_Traffic_2020_11,Seoul_Traffic_2020_12])
Seoul_Traffic_2020=Seoul_Traffic_2020.groupby('일자').sum()
Seoul_Traffic_2020.index=pd.to_datetime(Seoul_Traffic_2020.index.astype(int),format='%Y%m%d')
Seoul_Traffic_2020['Total_Traffic']=Seoul_Traffic_2020['0시']+Seoul_Traffic_2020['1시']+Seoul_Traffic_2020['2시']+Seoul_Traffic_2020['3시']+Seoul_Traffic_2020['4시']+Seoul_Traffic_2020['5시']+Seoul_Traffic_2020['6시']+Seoul_Traffic_2020['7시']+Seoul_Traffic_2020['8시']+Seoul_Traffic_2020['9시']+Seoul_Traffic_2020['10시']+Seoul_Traffic_2020['11시']+Seoul_Traffic_2020['12시']+Seoul_Traffic_2020['13시']+Seoul_Traffic_2020['14시']+Seoul_Traffic_2020['15시']+Seoul_Traffic_2020['16시']+Seoul_Traffic_2020['17시']+Seoul_Traffic_2020['18시']+Seoul_Traffic_2020['19시']+Seoul_Traffic_2020['20시']+Seoul_Traffic_2020['21시']+Seoul_Traffic_2020['22시']+Seoul_Traffic_2020['23시']
Seoul_Traffic_2020=pd.DataFrame(Seoul_Traffic_2020['Total_Traffic'])

# %%
#서울 2021년 교통량 합산

Seoul_Traffic_2021_1=pd.read_csv('data/2021_Seoul_Traffic/01월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2021_2=pd.read_csv('data/2021_Seoul_Traffic/02월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2021_3=pd.read_csv('data/2021_Seoul_Traffic/03월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2021_4=pd.read_csv('data/2021_Seoul_Traffic/04월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2021_5=pd.read_csv('data/2021_Seoul_Traffic/05월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2021_6=pd.read_csv('data/2021_Seoul_Traffic/06월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2021_7=pd.read_csv('data/2021_Seoul_Traffic/07월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2021_8=pd.read_csv('data/2021_Seoul_Traffic/08월 서울시 교통량 조사자료.csv',encoding='cp949')[['일자','0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시']]
Seoul_Traffic_2021=pd.concat([Seoul_Traffic_2021_1, Seoul_Traffic_2021_2,Seoul_Traffic_2021_3, Seoul_Traffic_2021_4,
                             Seoul_Traffic_2021_5,Seoul_Traffic_2021_6,Seoul_Traffic_2021_7,Seoul_Traffic_2021_8])
Seoul_Traffic_2021=Seoul_Traffic_2021.groupby('일자').sum()
Seoul_Traffic_2021.index=pd.to_datetime(Seoul_Traffic_2021.index.astype(int),format='%Y%m%d')
Seoul_Traffic_2021['Total_Traffic']=Seoul_Traffic_2021['0시']+Seoul_Traffic_2021['1시']+Seoul_Traffic_2021['2시']+Seoul_Traffic_2021['3시']+Seoul_Traffic_2021['4시']+Seoul_Traffic_2021['5시']+Seoul_Traffic_2021['6시']+Seoul_Traffic_2021['7시']+Seoul_Traffic_2021['8시']+Seoul_Traffic_2021['9시']+Seoul_Traffic_2021['10시']+Seoul_Traffic_2021['11시']+Seoul_Traffic_2021['12시']+Seoul_Traffic_2021['13시']+Seoul_Traffic_2021['14시']+Seoul_Traffic_2021['15시']+Seoul_Traffic_2021['16시']+Seoul_Traffic_2021['17시']+Seoul_Traffic_2021['18시']+Seoul_Traffic_2021['19시']+Seoul_Traffic_2021['20시']+Seoul_Traffic_2021['21시']+Seoul_Traffic_2021['22시']+Seoul_Traffic_2021['23시']
Seoul_Traffic_2021=pd.DataFrame(Seoul_Traffic_2021['Total_Traffic'])

# %%
#2021-2021년 교통량 concat

Seoul_Traffic=pd.concat([Seoul_Traffic_2020, Seoul_Traffic_2021])
Seoul_Traffic
# Out:
#             Total_Traffic
# 일자
# 2020-01-01      7347299.0
# 2020-01-02      9326734.0
# 2020-01-03      9998638.0
# 2020-01-04      9198233.0
# 2020-01-05      7868358.0
# ...                   ...
# 2021-08-27      9506229.0
# 2021-08-28      8748341.0
# 2021-08-29      7473739.0
# 2021-08-30      9288151.0
# 2021-08-31      9023964.0
#
# [609 rows x 1 columns]

# %%
# 일자를 기준으로 확진자수, 총교통량 병합

data_mart_seoul=seoul_covid_data.join(Seoul_Traffic, how='right')
data_mart_seoul['date']=data_mart_seoul.index
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
data_mart_seoul['day_of_week']=data_mart_seoul.index.dayofweek
data_mart_seoul.day_of_week=data_mart_seoul.day_of_week.apply(lambda x : days[x])
data_mart_seoul['year']=data_mart_seoul.index.year
data_mart_seoul['month']=data_mart_seoul.index.month
data_mart_seoul.daily_decideCnt=data_mart_seoul.daily_decideCnt.fillna(0)
data_mart_seoul['categorize_100']=data_mart_seoul.daily_decideCnt//100
data_mart_seoul.head()
# Out:
#             daily_decideCnt  categorize_100  Total_Traffic       date  \
# 일자
# 2020-01-01              0.0             0.0      7347299.0 2020-01-01
# 2020-01-02              0.0             0.0      9326734.0 2020-01-02
# 2020-01-03              0.0             0.0      9998638.0 2020-01-03
# 2020-01-04              0.0             0.0      9198233.0 2020-01-04
# 2020-01-05              0.0             0.0      7868358.0 2020-01-05
#
#            day_of_week  year  month
# 일자
# 2020-01-01         WED  2020      1
# 2020-01-02         THU  2020      1
# 2020-01-03         FRI  2020      1
# 2020-01-04         SAT  2020      1
# 2020-01-05         SUN  2020      1

# %%
# 년도별 확진자수 카테고리 분포

plt.figure(figsize=(12,10))
plt.title('\nDistribution By Unit Of The Number Of Confirmed Cases Of Seoul\n')
sns.countplot(x='categorize_100',data=data_mart_seoul,hue='year')
# Out:
# <AxesSubplot:title={'center':'\nDistribution By Unit Of The Number Of Confirmed Cases Of Seoul\n'}, xlabel='categorize_100', ylabel='count'>

# %%
# 월별, 연도별 교통량

plt.figure(figsize=(13,8))
plt.title('\nMonthly Traffic Volume In Seoul\n')
sns.lineplot(x='month',y='Total_Traffic', hue='year',data=data_mart_seoul[data_mart_seoul.day_of_week=='SAT'])
# Out:
# <AxesSubplot:title={'center':'\nMonthly Traffic Volume In Seoul\n'}, xlabel='month', ylabel='Total_Traffic'>

# %%
#확진자수(100unit)에 따른 평균 총교통량

plt.figure(figsize=(12,8))
plt.title('Total Traffic By 100 Unit Of Confirmed Cases In Seoul')
sns.lineplot(x='categorize_100', y='Total_Traffic',data=data_mart_seoul,hue='year')
# Out:
# <AxesSubplot:title={'center':'Total Traffic By 100 Unit Of Confirmed Cases In Seoul'}, xlabel='categorize_100', ylabel='Total_Traffic'>

# %%
#좀 더 세분화해보자(50단위로 나누기)

data_mart_seoul['categorize_50']=data_mart_seoul.daily_decideCnt//50
data_mart_seoul.head()
# Out:
#             daily_decideCnt  categorize_100  Total_Traffic       date  \
# 일자
# 2020-01-01              0.0             0.0      7347299.0 2020-01-01
# 2020-01-02              0.0             0.0      9326734.0 2020-01-02
# 2020-01-03              0.0             0.0      9998638.0 2020-01-03
# 2020-01-04              0.0             0.0      9198233.0 2020-01-04
# 2020-01-05              0.0             0.0      7868358.0 2020-01-05
#
#            day_of_week  year  month  categorize_50
# 일자
# 2020-01-01         WED  2020      1            0.0
# 2020-01-02         THU  2020      1            0.0
# 2020-01-03         FRI  2020      1            0.0
# 2020-01-04         SAT  2020      1            0.0
# 2020-01-05         SUN  2020      1            0.0

# %%
plt.figure(figsize=(12,10))
sns.countplot(x='categorize_50',data=data_mart_seoul,hue='year')
# Out:
# <AxesSubplot:xlabel='categorize_50', ylabel='count'>

# %%
#확진자수(50unit)에 따른 평균 총교통량

plt.figure(figsize=(12,8))
plt.title('Distribution By 50 Unit Of Confirmed Cases In Seoul')
sns.lineplot(x='categorize_50', y='Total_Traffic',data=data_mart_seoul,hue='year')
# Out:
# <AxesSubplot:title={'center':'Distribution By 50 Unit Of Confirmed Cases In Seoul'}, xlabel='categorize_50', ylabel='Total_Traffic'>

# %% [markdown]
# ## 연휴철 교통량 및 확진자 수 분석
#
# 1월(연초행사), 2월(설), 5월(어린이날) 중심으로 분석

# %% [markdown]
# ### 1분기(1월, 2월) 분석

# %%
#1분기 데이터 합치기
fitst_traffic_data=pd.concat([traffic_2020_01,traffic_2021_01])

# %%
#1분기데이터 년도, 월 칼럼추가
fitst_traffic_data.index=fitst_traffic_data.집계일자
fitst_traffic_data=fitst_traffic_data.drop('집계일자',axis=1)
fitst_traffic_data=fitst_traffic_data[['영업소명','1종교통량', '2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량', '총교통량']]
fitst_traffic_data.index=pd.to_datetime(fitst_traffic_data.index, format='%Y%m%d')
fitst_traffic_data['year']=fitst_traffic_data.index.year 
fitst_traffic_data['month']=fitst_traffic_data.index.month

# %% [markdown]
# #### 1월(연초행사) 중심 분석

# %%
# 2021 1분기중 1월로만 그룹화
jan_traffic_data=fitst_traffic_data[(fitst_traffic_data['year']==2021)&(fitst_traffic_data['month']==1)]
jan_traffic_data=jan_traffic_data.groupby('집계일자')['1종교통량', '2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량', '총교통량'].sum()/(5.691220e+06)
jan_traffic_data['year']=jan_traffic_data.index.year
jan_traffic_data['month']=jan_traffic_data.index.month
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
jan_traffic_data['day_of_week']=jan_traffic_data.index.dayofweek
jan_traffic_data.day_of_week=jan_traffic_data.day_of_week.apply(lambda x : days[x])
jan_traffic_data.head()
# Out:
#                1종교통량     2종교통량     3종교통량     4종교통량     5종교통량     6종교통량  \
# 집계일자
# 2021-01-01  0.735260  0.012763  0.018119  0.011001  0.009212  0.030090
# 2021-01-02  0.802033  0.015176  0.020166  0.011540  0.014465  0.034260
# 2021-01-03  0.726511  0.008409  0.015943  0.009004  0.007977  0.031782
# 2021-01-04  0.868189  0.036668  0.043541  0.037274  0.054478  0.048749
# 2021-01-05  0.856389  0.040266  0.046900  0.043832  0.061581  0.048008
#
#                 총교통량  year  month day_of_week
# 집계일자
# 2021-01-01  0.816446  2021      1         FRI
# 2021-01-02  0.897641  2021      1         SAT
# 2021-01-03  0.799626  2021      1         SUN
# 2021-01-04  1.088899  2021      1         MON
# 2021-01-05  1.096976  2021      1         TUE

# %%
#2021 1월 코로나 확진자 데이터 가져오기
covid_data['daily_decideCnt']=((covid_data.decideCnt.shift()-covid_data.decideCnt))/1020
jan_covid_data_new=covid_data[['stateDt','daily_decideCnt']]
jan_covid_data_new.index=pd.to_datetime(jan_covid_data_new['stateDt'],format='%Y%m%d')
jan_covid_data_new=jan_covid_data_new.drop('stateDt',axis=1)
jan_covid_traffic=jan_covid_data_new.join(jan_traffic_data,how='left')
jan_covid_traffic = jan_covid_traffic.dropna(axis=0)
jan_covid_traffic['집계일자']=jan_covid_traffic.index
jan_covid_traffic.head()
# Out:
#             daily_decideCnt     1종교통량     2종교통량     3종교통량     4종교통량     5종교통량  \
# stateDt
# 2021-01-31         0.299020  0.847764  0.009649  0.016889  0.009903  0.009623
# 2021-01-30         0.347059  0.939827  0.021057  0.026906  0.022306  0.034722
# 2021-01-29         0.447059  0.957940  0.038164  0.045617  0.038885  0.055170
# 2021-01-28         0.459804  0.851930  0.038533  0.046201  0.042250  0.058366
# 2021-01-27         0.487255  0.945442  0.040355  0.047042  0.042991  0.058943
#
#                6종교통량      총교통량    year  month day_of_week       집계일자
# stateDt
# 2021-01-31  0.036125  0.929953  2021.0    1.0         SUN 2021-01-31
# 2021-01-30  0.042135  1.086954  2021.0    1.0         SAT 2021-01-30
# 2021-01-29  0.051361  1.187137  2021.0    1.0         FRI 2021-01-29
# 2021-01-28  0.045590  1.082870  2021.0    1.0         THU 2021-01-28
# 2021-01-27  0.051469  1.186242  2021.0    1.0         WED 2021-01-27

# %%
#2021 1종 교통량(대부분의 자가용) 1월 토요일 분석
#주황색이 교통량, 파란색이 코로나

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set(title='\nTrend Of Korea\'s First Class Traffic On Saturday of January(2021)\n')
axes[1].set(title='\nTrend Of Korea\'s First Class Traffic On Sunday of January(2021)\n')

sns.lineplot(data=jan_covid_traffic[(jan_covid_traffic.day_of_week=='SAT')], x='집계일자', y='1종교통량', ax=axes[0],label='1종교통량')
sns.lineplot(data=jan_covid_traffic[(jan_covid_traffic.day_of_week=='SAT')], x='stateDt', y='daily_decideCnt', ax=axes[0],label='daily_decideCnt')

sns.lineplot(data=jan_covid_traffic[(jan_covid_traffic.day_of_week=='SUN')], x='집계일자', y='1종교통량', ax=axes[1],label='1종교통량')
sns.lineplot(data=jan_covid_traffic[(jan_covid_traffic.day_of_week=='SUN')], x='stateDt', y='daily_decideCnt', ax=axes[1],label='daily_decideCnt')
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Korea's First Class Traffic On Sunday of January(2021)\n"}, xlabel='집계일자', ylabel='1종교통량'>

# %% [markdown]
# #### 2월(설날) 중심 분석

# %%
# 2020 1분기중 2월로만 그룹화

feb_traffic_data=fitst_traffic_data[(fitst_traffic_data['year']==2020)&(fitst_traffic_data['month']==2)]
feb_traffic_data=feb_traffic_data.groupby('집계일자')['1종교통량', '2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량', '총교통량'].sum()/(5.877788e+06)
feb_traffic_data['year']=feb_traffic_data.index.year
feb_traffic_data['month']=feb_traffic_data.index.month
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
feb_traffic_data['day_of_week']=feb_traffic_data.index.dayofweek
feb_traffic_data.day_of_week=feb_traffic_data.day_of_week.apply(lambda x : days[x])
feb_traffic_data.head()
# Out:
#                1종교통량     2종교통량     3종교통량     4종교통량     5종교통량     6종교통량  \
# 집계일자
# 2020-02-01  0.873712  0.019559  0.031881  0.017592  0.027420  0.042296
# 2020-02-02  0.727833  0.008686  0.023428  0.007392  0.007229  0.034225
# 2020-02-03  0.872021  0.036686  0.047829  0.035328  0.050891  0.050681
# 2020-02-04  0.851268  0.038354  0.049710  0.039311  0.054722  0.049431
# 2020-02-05  0.830574  0.036885  0.048324  0.036217  0.052024  0.048338
#
#                 총교통량  year  month day_of_week
# 집계일자
# 2020-02-01  1.012459  2020      2         SAT
# 2020-02-02  0.808793  2020      2         SUN
# 2020-02-03  1.093436  2020      2         MON
# 2020-02-04  1.082795  2020      2         TUE
# 2020-02-05  1.052362  2020      2         WED

# %%
# 2021 1분기중 2월로만 그룹화

lastfeb_traffic_data=fitst_traffic_data[(fitst_traffic_data['year']==2021)&(fitst_traffic_data['month']==2)]
lastfeb_traffic_data=lastfeb_traffic_data.groupby('집계일자')['1종교통량', '2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량', '총교통량'].sum()/(6.639591e+06)
lastfeb_traffic_data['year']=lastfeb_traffic_data.index.year
lastfeb_traffic_data['month']=lastfeb_traffic_data.index.month
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
lastfeb_traffic_data['day_of_week']=lastfeb_traffic_data.index.dayofweek
lastfeb_traffic_data.day_of_week=lastfeb_traffic_data.day_of_week.apply(lambda x : days[x])
lastfeb_traffic_data.head()
# Out:
#                1종교통량     2종교통량     3종교통량     4종교통량     5종교통량     6종교통량  \
# 집계일자
# 2021-02-01  0.780393  0.032268  0.037997  0.032387  0.045009  0.043072
# 2021-02-02  0.786890  0.035401  0.040843  0.038070  0.051677  0.042959
# 2021-02-03  0.781969  0.034858  0.040817  0.038502  0.052838  0.042151
# 2021-02-04  0.752439  0.033535  0.039756  0.036923  0.050278  0.040003
# 2021-02-05  0.881208  0.035219  0.041369  0.037873  0.053373  0.046230
#
#                 총교통량  year  month day_of_week
# 집계일자
# 2021-02-01  0.971127  2021      2         MON
# 2021-02-02  0.995841  2021      2         TUE
# 2021-02-03  0.991135  2021      2         WED
# 2021-02-04  0.952934  2021      2         THU
# 2021-02-05  1.095271  2021      2         FRI

# %%
#2020 2월 코로나 확진자 데이터 가져오기
covid_data['daily_decideCnt']=((covid_data.decideCnt.shift()-covid_data.decideCnt))/813
feb_covid_data_new=covid_data[['stateDt','daily_decideCnt']]
feb_covid_data_new.index=pd.to_datetime(feb_covid_data_new['stateDt'],format='%Y%m%d')
feb_covid_data_new=feb_covid_data_new.drop('stateDt',axis=1)
feb_covid_data_new['year']=feb_covid_data_new.index.year
feb_covid_data_new['month']=feb_covid_data_new.index.month
feb_covid_data_new=feb_covid_data_new[(feb_covid_data_new['year']==2020)]
feb_covid_data_new=feb_covid_data_new[(feb_covid_data_new['month']==2)]
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
feb_covid_data_new['day_of_week']=feb_covid_data_new.index.dayofweek
feb_covid_data_new.day_of_week=feb_covid_data_new.day_of_week.apply(lambda x : days[x])
feb_covid_data_new.head()
# Out:
#             daily_decideCnt  year  month day_of_week
# stateDt
# 2020-02-29         0.720787  2020      2         SAT
# 2020-02-28         1.000000  2020      2         FRI
# 2020-02-27         0.702337  2020      2         THU
# 2020-02-26         0.621156  2020      2         WED
# 2020-02-25         0.349323  2020      2         TUE

# %%
#2021 2월 코로나 확진자 데이터 가져오기
covid_data['daily_decideCnt']=((covid_data.decideCnt.shift()-covid_data.decideCnt))/621
lastfeb_covid_data_n=covid_data[['stateDt','daily_decideCnt']]
lastfeb_covid_data_n.index=pd.to_datetime(lastfeb_covid_data_n['stateDt'],format='%Y%m%d')
lastfeb_covid_data_n=lastfeb_covid_data_n.drop('stateDt',axis=1)
lastfeb_covid_data_n['year']=lastfeb_covid_data_n.index.year
lastfeb_covid_data_n['month']=lastfeb_covid_data_n.index.month
lastfeb_covid_data_n=lastfeb_covid_data_n[(lastfeb_covid_data_n['year']==2021)]
lastfeb_covid_data_n=lastfeb_covid_data_n[(lastfeb_covid_data_n['month']==2)]
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
lastfeb_covid_data_n['day_of_week']=lastfeb_covid_data_n.index.dayofweek
lastfeb_covid_data_n.day_of_week=lastfeb_covid_data_n.day_of_week.apply(lambda x : days[x])
lastfeb_covid_data_n.head()
# Out:
#             daily_decideCnt  year  month day_of_week
# stateDt
# 2021-02-28         0.571659  2021      2         SUN
# 2021-02-27         0.571659  2021      2         SAT
# 2021-02-26         0.668277  2021      2         FRI
# 2021-02-25         0.623188  2021      2         THU
# 2021-02-24         0.636071  2021      2         WED

# %%
#2020 1종 교통량(대부분의 자가용) 1월 토요일/일요일 분석
#주황색이 교통량, 파란색이 코로나

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set(title='\nTrend Of Korea\'s First Class Traffic On Saturday of February(2020)\n')
axes[1].set(title='\nTrend Of Korea\'s First Class Traffic On Sunday of February(2020)\n')

sns.lineplot(data=feb_traffic_data[(feb_traffic_data.day_of_week=='SAT')], x='집계일자', y='1종교통량',ax=axes[0],label='1종교통량')
sns.lineplot(data=feb_covid_data_new[(feb_covid_data_new.day_of_week=='SAT')], x='stateDt', y='daily_decideCnt',ax=axes[0],label='daily_decideCnt')

sns.lineplot(data=feb_traffic_data[(feb_traffic_data.day_of_week=='SUN')], x='집계일자', y='1종교통량', ax=axes[1],label='1종교통량')
sns.lineplot(data=feb_covid_data_new[(feb_covid_data_new.day_of_week=='SUN')], x='stateDt', y='daily_decideCnt', ax=axes[1],label='daily_decideCnt')
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Korea's First Class Traffic On Sunday of February(2020)\n"}, xlabel='집계일자', ylabel='1종교통량'>

# %%
#2021 1종 교통량(대부분의 자가용) 1월 토요일/일요일 분석
#주황색이 교통량, 파란색이 코로나

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set(title='\nTrend Of Korea\'s First Class Traffic On Saturday of February(2021)\n')
axes[1].set(title='\nTrend Of Korea\'s First Class Traffic On Sunday of February(2021)\n')

sns.lineplot(data=lastfeb_traffic_data[(lastfeb_traffic_data.day_of_week=='SAT')], x='집계일자', y='1종교통량',ax=axes[0],label='1종교통량')
sns.lineplot(data=lastfeb_covid_data_n[(lastfeb_covid_data_n.day_of_week=='SAT')], x='stateDt', y='daily_decideCnt',ax=axes[0],label='daily_decideCnt')

sns.lineplot(data=lastfeb_traffic_data[(lastfeb_traffic_data.day_of_week=='SUN')], x='집계일자', y='1종교통량',ax=axes[1],label='1종교통량')
sns.lineplot(data=lastfeb_covid_data_n[(lastfeb_covid_data_n.day_of_week=='SUN')], x='stateDt', y='daily_decideCnt',ax=axes[1],label='daily_decideCnt')
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Korea's First Class Traffic On Sunday of February(2021)\n"}, xlabel='집계일자', ylabel='1종교통량'>

# %% [markdown]
# ### 2분기(5월) 중점 분석

# %%
#2분기 데이터 합치기
traffic_data=pd.concat([traffic_2018_02,traffic_2019_02,traffic_2020_02,traffic_2021_02])

# %%
#2분기데이터 칼럼추가
traffic_data.index=traffic_data.집계일자
traffic_data=traffic_data.drop('집계일자',axis=1)
traffic_data=traffic_data[['영업소명','1종교통량', '2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량', '총교통량']]
traffic_data.index=pd.to_datetime(traffic_data.index, format='%Y%m%d')
traffic_data['year']=traffic_data.index.year 
traffic_data['month']=traffic_data.index.month

# %%
# 2020 2분기중 5월로만 그룹화
may_traffic_data=traffic_data[(traffic_data['month']==5)&(traffic_data['year']==2020)]
may_traffic_data=may_traffic_data.groupby('집계일자')['1종교통량', '2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량', '총교통량'].sum()/(6.935460e+06)
may_traffic_data['year']=may_traffic_data.index.year
may_traffic_data['month']=may_traffic_data.index.month
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
may_traffic_data['day_of_week']=may_traffic_data.index.dayofweek
may_traffic_data.day_of_week=may_traffic_data.day_of_week.apply(lambda x : days[x])
may_traffic_data.head()
# Out:
#                1종교통량     2종교통량     3종교통량     4종교통량     5종교통량     6종교통량  \
# 집계일자
# 2020-05-01  0.955621  0.018704  0.021363  0.014813  0.015611  0.040540
# 2020-05-02  1.000000  0.014837  0.018595  0.011872  0.017734  0.040107
# 2020-05-03  0.855849  0.006997  0.012975  0.006215  0.005399  0.034197
# 2020-05-04  0.885235  0.027365  0.030290  0.025014  0.039644  0.044980
# 2020-05-05  0.778792  0.017429  0.020559  0.016616  0.025193  0.033642
#
#                 총교통량  year  month day_of_week
# 집계일자
# 2020-05-01  1.066653  2020      5         FRI
# 2020-05-02  1.103145  2020      5         SAT
# 2020-05-03  0.921633  2020      5         SUN
# 2020-05-04  1.052528  2020      5         MON
# 2020-05-05  0.892231  2020      5         TUE

# %%
# 2021 2분기중 5월로만 그룹화
lastmay_traffic_data=traffic_data[(traffic_data['month']==5)&(traffic_data['year']==2021)]
lastmay_traffic_data=lastmay_traffic_data.groupby('집계일자')['1종교통량', '2종교통량','3종교통량', '4종교통량', '5종교통량', '6종교통량', '총교통량'].sum()/(7.160452e+06)
lastmay_traffic_data['year']=lastmay_traffic_data.index.year
lastmay_traffic_data['month']=lastmay_traffic_data.index.month
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
lastmay_traffic_data['day_of_week']=lastmay_traffic_data.index.dayofweek
lastmay_traffic_data.day_of_week=lastmay_traffic_data.day_of_week.apply(lambda x : days[x])
lastmay_traffic_data.head()
# Out:
#                1종교통량     2종교통량     3종교통량     4종교통량     5종교통량     6종교통량  \
# 집계일자
# 2021-05-01  0.876654  0.014430  0.019400  0.012241  0.016021  0.035950
# 2021-05-02  0.856370  0.007681  0.013986  0.006861  0.006599  0.034029
# 2021-05-03  0.841758  0.032650  0.038008  0.031922  0.048869  0.043529
# 2021-05-04  0.835254  0.032601  0.039228  0.034168  0.050682  0.042789
# 2021-05-05  0.820242  0.018291  0.022196  0.017091  0.026270  0.033389
#
#                 총교통량  year  month day_of_week
# 집계일자
# 2021-05-01  0.974696  2021      5         SAT
# 2021-05-02  0.925527  2021      5         SUN
# 2021-05-03  1.036736  2021      5         MON
# 2021-05-04  1.034723  2021      5         TUE
# 2021-05-05  0.937481  2021      5         WED

# %%
covid_data=pd.read_csv('data/Covid_case.csv')
covid_data.head()

# 2020년 코로나 일별 확진자 수 칼럼 추가
# 정수형 stateDt를 Datetime형 stateDt로 변환 후 인덱스로 설정

covid_data['daily_decideCnt']=(covid_data.decideCnt.shift()-covid_data.decideCnt)/79
covid_data_new=covid_data[['stateDt','daily_decideCnt']]
covid_data_new.index=pd.to_datetime(covid_data_new['stateDt'],format='%Y%m%d')
covid_data_new=covid_data_new.drop('stateDt',axis=1)
covid_data_new['year']=covid_data_new.index.year
covid_data_new['month']=covid_data_new.index.month
covid_data_new=covid_data_new[(covid_data_new['month']==5)]
covid_data_new=covid_data_new[(covid_data_new['year']==2020)]
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
covid_data_new['day_of_week']=covid_data_new.index.dayofweek
covid_data_new.day_of_week=covid_data_new.day_of_week.apply(lambda x : days[x])
covid_data_new.head()
# Out:
#             daily_decideCnt  year  month day_of_week
# stateDt
# 2020-05-31         0.443038  2020      5         SUN
# 2020-05-30         0.341772  2020      5         SAT
# 2020-05-29         0.493671  2020      5         FRI
# 2020-05-28         0.734177  2020      5         THU
# 2020-05-27         1.000000  2020      5         WED

# %%
# 2021년 코로나 일별 확진자 수 칼럼 추가
# 정수형 stateDt를 Datetime형 stateDt로 변환 후 인덱스로 설정

covid_data['daily_decideCnt']=(covid_data.decideCnt.shift()-covid_data.decideCnt)/747
covid_data_n=covid_data[['stateDt','daily_decideCnt']]
covid_data_n.index=pd.to_datetime(covid_data_n['stateDt'],format='%Y%m%d')
covid_data_n=covid_data_n.drop('stateDt',axis=1)
covid_data_n['year']=covid_data_n.index.year
covid_data_n['month']=covid_data_n.index.month
covid_data_n=covid_data_n[(covid_data_n['month']==5)]
covid_data_n=covid_data_n[(covid_data_n['year']==2021)]
days={0:'MON',1:'TUE',2:'WED',3:'THU',4:'FRI',5:'SAT',6:'SUN'}
covid_data_n['day_of_week']=covid_data_n.index.dayofweek
covid_data_n.day_of_week=covid_data_n.day_of_week.apply(lambda x : days[x])
covid_data_n.head()
# Out:
#             daily_decideCnt  year  month day_of_week
# stateDt
# 2021-05-31         0.614458  2021      5         MON
# 2021-05-30         0.575636  2021      5         SUN
# 2021-05-29         0.642570  2021      5         SAT
# 2021-05-28         0.713521  2021      5         FRI
# 2021-05-27         0.785810  2021      5         THU

# %%
#2020 1종 교통량(대부분의 자가용) 1월 토요일/일요일 분석
#주황색이 교통량, 파란색이 코로나

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set(title='\nTrend Of Korea\'s First Class Traffic On Saturday of May(2020)\n')
axes[1].set(title='\nTrend Of Korea\'s First Class Traffic On Sunday of May(2020)\n')

sns.lineplot(data=may_traffic_data[(may_traffic_data.day_of_week=='SAT')], x='집계일자', y='1종교통량', ax=axes[0],label='1종교통량')
sns.lineplot(data=covid_data_new[(covid_data_new.day_of_week=='SAT')&((covid_data_new.year==2020))], x='stateDt', y='daily_decideCnt', ax=axes[0],label='daily_decideCnt')


sns.lineplot(data=may_traffic_data[(may_traffic_data.day_of_week=='SUN')], x='집계일자', y='1종교통량', ax=axes[1],label='1종교통량')
sns.lineplot(data=covid_data_new[(covid_data_new.day_of_week=='SUN')&((covid_data_new.year==2020))], x='stateDt', y='daily_decideCnt', ax=axes[1],label='daily_decideCnt')
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Korea's First Class Traffic On Sunday of May(2020)\n"}, xlabel='집계일자', ylabel='1종교통량'>

# %%
#2021 1종 교통량(대부분의 자가용) 1월 토요일/일요일 분석
#주황색이 교통량, 파란색이 코로나

fig, axes=plt.subplots(ncols=2)
fig.set_size_inches(20,5)

axes[0].set(title='\nTrend Of Korea\'s First Class Traffic On Saturday of May(2021)\n')
axes[1].set(title='\nTrend Of Korea\'s First Class Traffic On Sunday of May(2021)\n')

sns.lineplot(data=lastmay_traffic_data[(lastmay_traffic_data.day_of_week=='SAT')], x='집계일자', y='1종교통량', ax=axes[0],label='1종교통량')
sns.lineplot(data=covid_data_n[(covid_data_n.day_of_week=='SAT')&((covid_data_n.year==2021))], x='stateDt', y='daily_decideCnt', ax=axes[0],label='daily_decideCnt')

sns.lineplot(data=lastmay_traffic_data[(lastmay_traffic_data.day_of_week=='SUN')], x='집계일자', y='1종교통량',ax=axes[1],label='1종교통량')
sns.lineplot(data=covid_data_n[(covid_data_n.day_of_week=='SUN')&((covid_data_n.year==2021))], x='stateDt', y='daily_decideCnt',ax=axes[1],label='daily_decideCnt')
# Out:
# <AxesSubplot:title={'center':"\nTrend Of Korea's First Class Traffic On Sunday of May(2021)\n"}, xlabel='집계일자', ylabel='1종교통량'>
